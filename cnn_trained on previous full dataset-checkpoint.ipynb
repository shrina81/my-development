# %%
Image Classificationn model14//model data/<- top level folder

train
└───Passed <- training images
│   
│   │   │   1008104.jpg
│   │   │   1638227.jpg
│   │   │   ...      
│   └───Failed
│       │   1000205.jpg
│       │   1647351.jpg
│       │   ...
│test  
     Passed <- testing images
│  
│   │   │   1001116.jpg
│   │   │   1507019.jpg
│   │    ...      
│   └───Failed
│       │   100274.jpg
│       │   1653815.jpg
│       │   ...

# %%
D:/Users/JC8AB37/Image Classification Model14/full data/train/
D:/Users/JC8AB37/Image Classification Model14/model data/test/

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("D:/Users/JC8AB37/Image Classification Model14/full data/"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/'.
# There are 2 directories and 0 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/test'.
# There are 0 directories and 133 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/test\Failed_images'.
# There are 0 directories and 195 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/test\Passed_images'.
# There are 2 directories and 0 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/train'.
# There are 0 directories and 133 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/train\Failed_images'.
# There are 0 directories and 195 images in 'D:/Users/JC8AB37/Image Classification Model14/full data/train\Passed_images'.

# %%
# Another way to find out how many images are in a file
num_passed_images_train = len(os.listdir("D:/Users/JC8AB37/Image Classification Model14/full data/train/Passed_images"))

num_passed_images_train
# Out:
# 195

# %%
# Another way to find out how many images are in a file
num_passed_images_train = len(os.listdir("D:/Users/JC8AB37/Image Classification Model14/full data/train/Failed_images"))

num_passed_images_train
# Out:
# 133

# %%
# Another way to find out how many images are in a file
num_passed_images_test = len(os.listdir("D:/Users/JC8AB37/Image Classification Model14/full data/test/Passed_images"))

num_passed_images_test
# Out:
# 195

# %%
# Another way to find out how many images are in a file
num_passed_images_test = len(os.listdir("D:/Users/JC8AB37/Image Classification Model14/full data/test/Failed_images"))

num_passed_images_test
# Out:
# 133

# %%
# Another way to find out how many images are in a file
num_passed_images_test = len(os.listdir("D:/Users/JC8AB37/Image Classification Model14/full data/test/Passed_images"))

num_passed_images_test
# Out:
# 195

# %%
# Get the class names (programmatically, this is much more helpful with a longer list of classes)
import pathlib
import numpy as np
data_dir = pathlib.Path("D:/Users/JC8AB37/Image Classification Model14/full data/train/") # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['Failed_images' 'Passed_images']

# %%
# Get the class names (programmatically, this is much more helpful with a longer list of classes)
import pathlib
import numpy as np
data_dir = pathlib.Path("D:/Users/JC8AB37/Image Classification Model14/full data/test/") # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['Failed_images' 'Passed_images']

# %%
# View an image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir="D:/Users/JC8AB37/Image Classification Model14/full data/train//",
                        target_class="Passed_Images")
# Out:
# Image shape: (3096, 4128, 3)

# %%
# View a random image from the training dataset
img = view_random_image(target_dir="D:/Users/JC8AB37/Image Classification Model14/full data/test//",
                        target_class="Failed_Images")
# Out:
# Image shape: (3096, 4128, 3)

# %%
# View the image shape
img.shape # returns (width, height, colour channels)
# Out:
# (3096, 4128, 3)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set the seed
tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 1 and 0, also called scaling/normalization)
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Setup the train and test directories
train_dir ="D:/Users/JC8AB37/Image Classification Model14/full data/train/"
test_dir = "D:/Users/JC8AB37/Image Classification Model14/full data/test/"

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=32, # number of images to process at a time 
                                               target_size=(224, 224), # convert all images to be 224 x 224
                                               class_mode="binary", # type of problem we're working on
                                               seed=42)

valid_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)
# Out:
# Found 328 images belonging to 2 classes.
# Found 328 images belonging to 2 classes.

# %%
type(train_data[0][0])
# Out:
# numpy.ndarray

# %%
train_data[0][0].shape
# Out:
# (32, 224, 224, 3)

# %% [raw]
# train_data.shape

# %%
# Get a sample of the training data batch 
images, labels = train_data.next() # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %%
train_data

# %%
# Get the first two images
images[:2], images[0].shape
# Out:
# (array([[[[0.854902  , 0.8313726 , 0.8313726 ],
#           [0.854902  , 0.8196079 , 0.8235295 ],
#           [0.8470589 , 0.8000001 , 0.8000001 ],
#           ...,
#           [0.9960785 , 0.9921569 , 0.9843138 ],
#           [0.9450981 , 0.9294118 , 0.92549026],
#           [0.9803922 , 0.96470594, 0.9686275 ]],
#
#          [[0.86666673, 0.8431373 , 0.8431373 ],
#           [0.85098046, 0.82745105, 0.82745105],
#           [0.8588236 , 0.82745105, 0.8196079 ],
#           ...,
#           [0.9921569 , 0.97647065, 0.9725491 ],
#           [0.9686275 , 0.95294124, 0.9490197 ],
#           [0.97647065, 0.9607844 , 0.96470594]],
#
#          [[0.8588236 , 0.82745105, 0.8196079 ],
#           [0.8588236 , 0.8352942 , 0.8352942 ],
#           [0.854902  , 0.83921576, 0.8352942 ],
#           ...,
#           [1.        , 0.98823535, 0.9843138 ],
#           [0.9803922 , 0.96470594, 0.9686275 ],
#           [0.9843138 , 0.9686275 , 0.9725491 ]],
#
#          ...,
#
#          [[0.20784315, 0.34509805, 0.57254905],
#           [0.20392159, 0.32941177, 0.5529412 ],
#           [0.09411766, 0.18431373, 0.34901962],
#           ...,
#           [0.9960785 , 0.97647065, 0.9607844 ],
#           [1.        , 0.9921569 , 0.97647065],
#           [1.        , 0.9843138 , 0.9725491 ]],
#
#          [[0.20000002, 0.3254902 , 0.54901963],
#           [0.1764706 , 0.29803923, 0.52156866],
#           [0.10588236, 0.18823531, 0.35686275],
#           ...,
#           [1.        , 0.98823535, 0.97647065],
#           [1.        , 0.9843138 , 0.9725491 ],
#           [1.        , 0.9921569 , 0.9803922 ]],
#
#          [[0.227451  , 0.34117648, 0.56078434],
#           [0.227451  , 0.32941177, 0.5529412 ],
#           [0.10980393, 0.20392159, 0.38431376],
#           ...,
#           [1.        , 0.9960785 , 0.9843138 ],
#           [1.        , 0.98823535, 0.97647065],
#           [1.        , 0.98823535, 0.97647065]]],
#
#
#         [[[0.15686275, 0.35686275, 0.18823531],
#           [0.12941177, 0.28627452, 0.15294118],
#           [0.12156864, 0.19215688, 0.12941177],
#           ...,
#           [0.1254902 , 0.10196079, 0.10980393],
#           [0.10980393, 0.09411766, 0.09803922],
#           [0.12156864, 0.10588236, 0.10980393]],
#
#          [[0.14509805, 0.34509805, 0.1764706 ],
#           [0.12156864, 0.2784314 , 0.14509805],
#           [0.13725491, 0.23137257, 0.14509805],
#           ...,
#           [0.12941177, 0.10588236, 0.1137255 ],
#           [0.1254902 , 0.10196079, 0.10980393],
#           [0.12156864, 0.10588236, 0.10980393]],
#
#          [[0.15686275, 0.36078432, 0.18039216],
#           [0.13333334, 0.2901961 , 0.15686275],
#           [0.10980393, 0.21960786, 0.12156864],
#           ...,
#           [0.14117648, 0.11764707, 0.1254902 ],
#           [0.11764707, 0.09411766, 0.10196079],
#           [0.13725491, 0.1137255 , 0.12156864]],
#
#          ...,
#
#          [[0.5686275 , 0.5294118 , 0.4901961 ],
#           [0.57254905, 0.53333336, 0.49411768],
#           [0.5686275 , 0.5137255 , 0.47058827],
#           ...,
#           [0.6117647 , 0.454902  , 0.21568629],
#           [0.6039216 , 0.44705886, 0.20784315],
#           [0.6039216 , 0.44705886, 0.21568629]],
#
#          [[0.48627454, 0.427451  , 0.40000004],
#           [0.4784314 , 0.427451  , 0.39607847],
#           [0.5058824 , 0.454902  , 0.42352945],
#           ...,
#           [0.6117647 , 0.45882356, 0.20392159],
#           [0.6156863 , 0.454902  , 0.21176472],
#           [0.6039216 , 0.43921572, 0.20392159]],
#
#          [[0.427451  , 0.38823533, 0.3529412 ],
#           [0.38823533, 0.34901962, 0.30980393],
#           [0.40000004, 0.3647059 , 0.30588236],
#           ...,
#           [0.6313726 , 0.47058827, 0.21960786],
#           [0.62352943, 0.45098042, 0.19607845],
#           [0.62352943, 0.45098042, 0.19607845]]]], dtype=float32),
#  (224, 224, 3))

# %%
# View the first batch of labels
labels

# %%
# Create a CNN model 
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=10, 
                         kernel_size=3, # can also be (3, 3)
                         activation="relu", 
                         input_shape=(224, 224, 3)), # first layer specifies input shape (height, width, colour channels)
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, # pool_size can also be (2, 2)
                            padding="valid"), # padding can also be 'same'
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.Conv2D(10, 3, activation="relu"), # activation='relu' == tf.keras.layers.Activations(tf.nn.relu)
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1, activation="sigmoid") # binary activation output
])

# %%
# Compile the model
model.compile(loss="binary_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# %%
# Fit the model
history = model.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/5
# 11/11 [==============================] - 201s 19s/step - loss: 0.6609 - accuracy: 0.5976 - val_loss: 0.6137 - val_accuracy: 0.5945
# Epoch 2/5
# 11/11 [==============================] - 196s 18s/step - loss: 0.5518 - accuracy: 0.7805 - val_loss: 0.4666 - val_accuracy: 0.7866
# Epoch 3/5
# 11/11 [==============================] - 195s 18s/step - loss: 0.3909 - accuracy: 0.8567 - val_loss: 0.2930 - val_accuracy: 0.9024
# Epoch 4/5
# 11/11 [==============================] - 198s 19s/step - loss: 0.2485 - accuracy: 0.9207 - val_loss: 0.2098 - val_accuracy: 0.9573
# Epoch 5/5
# 11/11 [==============================] - 193s 18s/step - loss: 0.1850 - accuracy: 0.9482 - val_loss: 0.1182 - val_accuracy: 0.9787

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 1)                 28091
#
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
def representative_data_gen():
  for input_value in tf.data.Dataset.from_tensor_slices(train_data[0][0]).batch(1).take(10):
    yield [input_value]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset =r epresentative_data_gen
# Ensure that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# Set the input and output tensors to uint8 (APIs added in r2.3)
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

tflite_model_quant = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: D:\Users\JC8AB37\AppData\Local\Temp\tmp0qen54ws\assets
# C:\ProgramData\Anaconda3\envs\shop_vir\lib\site-packages\tensorflow\lite\python\convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
interpreter = tf.lite.Interpreter(model_content=tflite_model_quant)
input_type = interpreter.get_input_details()[0]['dtype']
print('input: ', input_type)
output_type = interpreter.get_output_details()[0]['dtype']
print('output: ', output_type)
# Out:
# input:  <class 'numpy.uint8'>
# output:  <class 'numpy.uint8'>

# %%
type(tflite_model_quant)
# Out:
# bytes

# %%
with open("D:/ok-nok/tflite_model_quant.tflite","wb") as f:
    f.write(tflite_model_quant)

# %%
import pathlib

tflite_models_dir = pathlib.Path("D:/ok-nok/dataset/")
tflite_models_dir.mkdir(exist_ok=True, parents=True)

# Save the unquantized/float model:
#tflite_model_file = tflite_models_dir/"ok_nok.tflite"
#tflite_model_file.write_bytes(tflite_model)

# Save the quantized model:
tflite_model_quant_file = tflite_models_dir/"ok_nok.tflite.tflite"
tflite_model_quant_file.write_bytes(tflite_model_quant)
# Out:
# 36648

# %%
# Helper function to run inference on a TFLite model
def run_tflite_model(tflite_file, test_image_indices):
  global valid_data

  # Initialize the interpreter
  interpreter = tf.lite.Interpreter(model_path=str(tflite_file))
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  predictions = np.zeros((len(test_image_indices),), dtype=int)
  for i, test_image_index in enumerate(test_image_indices):
    valid_data = valid_data[test_image_index]
    test_label = test_labels[test_image_index]

    # Check if the input type is quantized, then rescale input data to uint8
    if input_details['dtype'] == np.uint8:
      input_scale, input_zero_point = input_details["quantization"]
      test_image = test_image / input_scale + input_zero_point

    test_image = np.expand_dims(valid_data, axis=0).astype(input_details["dtype"])
    interpreter.set_tensor(input_details["index"], valid_data)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details["index"])[0]

    predictions[i] = output.argmax()

  return predictions

# %%
import matplotlib.pylab as plt

# Change this to test a different image
test_image_index = 1

## Helper function to test the models on one image
def test_model(tflite_file, test_image_index, model_type):
  global valid_data
  global test_labels

  predictions = run_tflite_model(tflite_file, [test_image_index])

  plt.imshow(test_images[test_image_index])
  template = model_type + " Model \n True:{true}, Predicted:{predict}"
  _ = plt.title(template.format(true= str(test_labels[test_image_index]), predict=str(predictions[0])))
  plt.grid(False)

# %%
test_model(tflite_model_quant_file, test_image_index, model_type="Quantized")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4776/3583720291.py in <module>
# ----> 1 test_model(tflite_model_quant_file, test_image_index, model_type="Quantized")
#
# ~\AppData\Local\Temp/ipykernel_4776/4068288472.py in test_model(tflite_file, test_image_index, model_type)
#       9   global test_labels
#      10
# ---> 11   predictions = run_tflite_model(tflite_file, [test_image_index])
#      12
#      13   plt.imshow(test_images[test_image_index])
#
# ~\AppData\Local\Temp/ipykernel_4776/328983418.py in run_tflite_model(tflite_file, test_image_indices)
#      13   for i, test_image_index in enumerate(test_image_indices):
#      14     valid_data = valid_data[test_image_index]
# ---> 15     test_label = test_labels[test_image_index]
#      16
#      17     # Check if the input type is quantized, then rescale input data to uint8
#
# NameError: name 'test_labels' is not defined

# %%
# Helper function to evaluate a TFLite model on all images
def evaluate_model(tflite_file, model_type):
  global test_images
  global test_labels

  test_image_indices = range(test_images.shape[0])
  predictions = run_tflite_model(tflite_file, test_image_indices)

  accuracy = (np.sum(test_labels== predictions) * 100) / len(test_images)

  print('%s model accuracy is %.4f%% (Number of test samples=%d)' % (
      model_type, accuracy, len(test_images)))

# %%
#evaluate_model(tflite_model_quant,model_type="Quantized")

# %%
evaluate_model(tflite_model_quant_file, model_type="Quantized")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4776/3649916578.py in <module>
# ----> 1 evaluate_model(tflite_model_quant_file, model_type="Quantized")
#
# ~\AppData\Local\Temp/ipykernel_4776/3226388646.py in evaluate_model(tflite_file, model_type)
#       4   global test_labels
#       5
# ----> 6   test_image_indices = range(test_images.shape[0])
#       7   predictions = run_tflite_model(tflite_file, test_image_indices)
#       8
#
# NameError: name 'test_images' is not defined

# %%
import pathlib

tflite_models_dir = pathlib.Path("D:/Users/JC8AB37/Image Classification Model14/full data/train/")
tflite_models_dir.mkdir(exist_ok=True, parents=True)

# Save the quantized model:
tflite_model_quant_file = tflite_models_dir/"mnist_model_quant.tflite"
tflite_model_quant_file.write_bytes(tflite_model_quant)
# Out:
# 36648

# %%
valid_data[0][0]
# Out:
# array([[[[0.21960786, 0.39607847, 0.07843138],
#          [0.21568629, 0.38431376, 0.0627451 ],
#          [0.20000002, 0.36078432, 0.08627451],
#          ...,
#          [0.24705884, 0.24313727, 0.2627451 ],
#          [0.2901961 , 0.28627452, 0.30588236],
#          [0.24705884, 0.2392157 , 0.2509804 ]],
#
#         [[0.21960786, 0.3921569 , 0.09019608],
#          [0.20784315, 0.37254903, 0.07450981],
#          [0.20784315, 0.37647063, 0.10588236],
#          ...,
#          [0.32156864, 0.32156864, 0.32941177],
#          [0.3254902 , 0.3254902 , 0.33333334],
#          [0.27058825, 0.27058825, 0.2784314 ]],
#
#         [[0.22352943, 0.4039216 , 0.11764707],
#          [0.21176472, 0.3803922 , 0.10980393],
#          [0.21960786, 0.37647063, 0.13333334],
#          ...,
#          [0.33333334, 0.33333334, 0.34117648],
#          [0.3019608 , 0.3019608 , 0.3019608 ],
#          [0.32941177, 0.32941177, 0.3372549 ]],
#
#         ...,
#
#         [[0.45882356, 0.7725491 , 0.9803922 ],
#          [0.46274513, 0.7803922 , 0.98823535],
#          [0.44705886, 0.7843138 , 0.9843138 ],
#          ...,
#          [0.6392157 , 0.6392157 , 0.6392157 ],
#          [0.8313726 , 0.8431373 , 0.81568635],
#          [0.7176471 , 0.74509805, 0.7176471 ]],
#
#         [[0.29411766, 0.62352943, 0.8588236 ],
#          [0.36862746, 0.7568628 , 0.98823535],
#          [0.39607847, 0.7607844 , 0.9843138 ],
#          ...,
#          [0.72156864, 0.7176471 , 0.70980394],
#          [0.7803922 , 0.7843138 , 0.7607844 ],
#          [0.5686275 , 0.6039216 , 0.58431375]],
#
#         [[0.3137255 , 0.5882353 , 0.8235295 ],
#          [0.30588236, 0.58431375, 0.82745105],
#          [0.31764707, 0.5686275 , 0.8196079 ],
#          ...,
#          [0.7176471 , 0.72156864, 0.7019608 ],
#          [0.5372549 , 0.56078434, 0.54509807],
#          [0.52156866, 0.5568628 , 0.54509807]]],
#
#
#        [[[0.54901963, 0.64705884, 0.56078434],
#          [0.5764706 , 0.69411767, 0.6       ],
#          [0.4666667 , 0.56078434, 0.45882356],
#          ...,
#          [0.        , 0.01960784, 0.06666667],
#          [0.00392157, 0.04705883, 0.11764707],
#          [0.        , 0.07058824, 0.15686275]],
#
#         [[0.3803922 , 0.41960788, 0.38431376],
#          [0.57254905, 0.6901961 , 0.59607846],
#          [0.49803925, 0.60784316, 0.50980395],
#          ...,
#          [0.00392157, 0.01960784, 0.06666667],
#          [0.01568628, 0.04705883, 0.12156864],
#          [0.01960784, 0.09019608, 0.1764706 ]],
#
#         [[0.3254902 , 0.33333334, 0.3137255 ],
#          [1.        , 1.        , 1.        ],
#          [0.3803922 , 0.427451  , 0.38823533],
#          ...,
#          [0.00392157, 0.03137255, 0.07058824],
#          [0.00392157, 0.03921569, 0.10588236],
#          [0.02352941, 0.09019608, 0.16862746]],
#
#         ...,
#
#         [[0.227451  , 0.25490198, 0.227451  ],
#          [0.21960786, 0.24705884, 0.21960786],
#          [0.5411765 , 0.6       , 0.57254905],
#          ...,
#          [0.7294118 , 0.7137255 , 0.7019608 ],
#          [0.82745105, 0.8078432 , 0.79215693],
#          [0.854902  , 0.8352942 , 0.8196079 ]],
#
#         [[0.23137257, 0.25882354, 0.23137257],
#          [0.2392157 , 0.25882354, 0.23529413],
#          [0.23529413, 0.2509804 , 0.24705884],
#          ...,
#          [0.8078432 , 0.77647066, 0.76470596],
#          [0.8352942 , 0.81568635, 0.8000001 ],
#          [0.85098046, 0.8313726 , 0.81568635]],
#
#         [[0.23529413, 0.2627451 , 0.23529413],
#          [0.23137257, 0.25882354, 0.23137257],
#          [0.20000002, 0.22352943, 0.20784315],
#          ...,
#          [0.7686275 , 0.7490196 , 0.7372549 ],
#          [0.8196079 , 0.8000001 , 0.7843138 ],
#          [0.8470589 , 0.81568635, 0.80392164]]],
#
#
#        [[[0.24313727, 0.41960788, 0.2901961 ],
#          [0.24705884, 0.42352945, 0.29411766],
#          [0.20392159, 0.37647063, 0.24705884],
#          ...,
#          [0.64705884, 0.4666667 , 0.13333334],
#          [0.627451  , 0.44705886, 0.20392159],
#          [0.5411765 , 0.36078432, 0.16862746]],
#
#         [[0.24705884, 0.42352945, 0.29411766],
#          [0.23529413, 0.40784317, 0.2784314 ],
#          [0.20392159, 0.3647059 , 0.2392157 ],
#          ...,
#          [0.6431373 , 0.47058827, 0.19215688],
#          [0.3921569 , 0.25882354, 0.1137255 ],
#          [0.7019608 , 0.68235296, 0.59607846]],
#
#         [[0.24313727, 0.41176474, 0.29411766],
#          [0.21960786, 0.3803922 , 0.2627451 ],
#          [0.1764706 , 0.3372549 , 0.21960786],
#          ...,
#          [0.6666667 , 0.61960787, 0.42352945],
#          [0.73333335, 0.74509805, 0.62352943],
#          [0.1137255 , 0.10980393, 0.10196079]],
#
#         ...,
#
#         [[0.36862746, 0.2901961 , 0.25490198],
#          [0.34901962, 0.2784314 , 0.2392157 ],
#          [0.40784317, 0.3372549 , 0.28235295],
#          ...,
#          [0.6117647 , 0.4431373 , 0.227451  ],
#          [0.6117647 , 0.44705886, 0.21960786],
#          [0.6117647 , 0.43529415, 0.20392159]],
#
#         [[0.3647059 , 0.28627452, 0.24313727],
#          [0.3803922 , 0.3019608 , 0.25882354],
#          [0.39607847, 0.32941177, 0.26666668],
#          ...,
#          [0.59607846, 0.43137258, 0.20392159],
#          [0.6117647 , 0.43529415, 0.20392159],
#          [0.6       , 0.427451  , 0.18823531]],
#
#         [[0.3647059 , 0.28627452, 0.25882354],
#          [0.37647063, 0.29803923, 0.25490198],
#          [0.38823533, 0.3137255 , 0.25882354],
#          ...,
#          [0.5921569 , 0.4156863 , 0.19215688],
#          [0.6039216 , 0.427451  , 0.19607845],
#          [0.6       , 0.427451  , 0.18823531]]],
#
#
#        ...,
#
#
#        [[[0.6039216 , 0.5411765 , 0.48235297],
#          [0.67058825, 0.63529414, 0.6       ],
#          [0.9294118 , 0.9686275 , 0.8235295 ],
#          ...,
#          [0.9058824 , 0.8705883 , 0.8431373 ],
#          [1.        , 0.9960785 , 1.        ],
#          [0.9215687 , 0.9058824 , 0.909804  ]],
#
#         [[0.7960785 , 0.7294118 , 0.6509804 ],
#          [0.8588236 , 0.79215693, 0.7294118 ],
#          [0.91372555, 0.9294118 , 0.79215693],
#          ...,
#          [0.9803922 , 0.96470594, 0.95294124],
#          [1.        , 0.9960785 , 0.9921569 ],
#          [0.97647065, 0.9725491 , 0.96470594]],
#
#         [[0.70980394, 0.59607846, 0.4784314 ],
#          [0.854902  , 0.7843138 , 0.69803923],
#          [0.94117653, 0.9294118 , 0.8000001 ],
#          ...,
#          [0.9921569 , 0.98823535, 0.9725491 ],
#          [0.93725497, 0.9176471 , 0.90196085],
#          [0.9803922 , 0.97647065, 0.9686275 ]],
#
#         ...,
#
#         [[0.73333335, 0.8588236 , 0.6627451 ],
#          [0.7411765 , 0.8862746 , 0.6862745 ],
#          [0.909804  , 0.9686275 , 0.854902  ],
#          ...,
#          [0.6509804 , 0.60784316, 0.58431375],
#          [0.9568628 , 0.94117653, 0.93725497],
#          [0.4901961 , 0.41960788, 0.37254903]],
#
#         [[0.8235295 , 0.9294118 , 0.7607844 ],
#          [0.78823537, 0.90196085, 0.72156864],
#          [0.7568628 , 0.8705883 , 0.6901961 ],
#          ...,
#          [0.8862746 , 0.8588236 , 0.8352942 ],
#          [0.9725491 , 0.9568628 , 0.9450981 ],
#          [0.7490196 , 0.7137255 , 0.69411767]],
#
#         [[0.81568635, 0.8705883 , 0.7725491 ],
#          [0.7803922 , 0.82745105, 0.7411765 ],
#          [0.75294125, 0.8000001 , 0.72156864],
#          ...,
#          [0.7137255 , 0.64705884, 0.60784316],
#          [0.7372549 , 0.68235296, 0.64705884],
#          [0.97647065, 0.9568628 , 0.94117653]]],
#
#
#        [[[0.34901962, 0.3254902 , 0.3254902 ],
#          [0.30588236, 0.28235295, 0.2901961 ],
#          [0.30588236, 0.2901961 , 0.29411766],
#          ...,
#          [0.9176471 , 0.85098046, 0.78823537],
#          [0.9215687 , 0.8588236 , 0.7960785 ],
#          [0.909804  , 0.8431373 , 0.76470596]],
#
#         [[0.34901962, 0.3254902 , 0.33333334],
#          [0.34117648, 0.31764707, 0.3254902 ],
#          [0.33333334, 0.3254902 , 0.32941177],
#          ...,
#          [0.9176471 , 0.85098046, 0.78823537],
#          [0.92549026, 0.86274517, 0.8000001 ],
#          [0.91372555, 0.8470589 , 0.77647066]],
#
#         [[0.3803922 , 0.35686275, 0.3647059 ],
#          [0.3647059 , 0.32941177, 0.33333334],
#          [0.35686275, 0.32156864, 0.3254902 ],
#          ...,
#          [0.909804  , 0.8470589 , 0.7843138 ],
#          [0.9333334 , 0.87843144, 0.82745105],
#          [0.9176471 , 0.86274517, 0.8117648 ]],
#
#         ...,
#
#         [[0.24705884, 0.2392157 , 0.25882354],
#          [0.23137257, 0.22352943, 0.23529413],
#          [0.22352943, 0.20784315, 0.21176472],
#          ...,
#          [0.3254902 , 0.28627452, 0.2784314 ],
#          [0.30980393, 0.2901961 , 0.2784314 ],
#          [0.29803923, 0.26666668, 0.25490198]],
#
#         [[0.20000002, 0.24705884, 0.3019608 ],
#          [0.19215688, 0.25882354, 0.32941177],
#          [0.21960786, 0.3019608 , 0.4156863 ],
#          ...,
#          [0.3137255 , 0.27450982, 0.26666668],
#          [0.2901961 , 0.25882354, 0.24705884],
#          [0.29411766, 0.2627451 , 0.2509804 ]],
#
#         [[0.16470589, 0.29803923, 0.4784314 ],
#          [0.20392159, 0.31764707, 0.4901961 ],
#          [0.21960786, 0.30980393, 0.48235297],
#          ...,
#          [0.3137255 , 0.2784314 , 0.25882354],
#          [0.29411766, 0.25882354, 0.2392157 ],
#          [0.3137255 , 0.2784314 , 0.25882354]]],
#
#
#        [[[1.        , 1.        , 1.        ],
#          [1.        , 1.        , 1.        ],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.7843138 , 0.64705884, 0.62352943],
#          [0.4784314 , 0.43529415, 0.45098042],
#          [0.12156864, 0.13333334, 0.16078432]],
#
#         [[1.        , 1.        , 1.        ],
#          [1.        , 1.        , 1.        ],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.7294118 , 0.5137255 , 0.5254902 ],
#          [0.14117648, 0.14117648, 0.18823531],
#          [0.16470589, 0.1764706 , 0.21176472]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.9960785 , 0.9960785 , 0.9960785 ],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.1137255 , 0.1254902 , 0.16078432],
#          [0.16470589, 0.1764706 , 0.21176472],
#          [0.1764706 , 0.20392159, 0.23529413]],
#
#         ...,
#
#         [[0.5294118 , 0.627451  , 0.46274513],
#          [0.5921569 , 0.69803923, 0.5294118 ],
#          [0.5254902 , 0.63529414, 0.44705886],
#          ...,
#          [0.23137257, 0.48235297, 0.61960787],
#          [0.25490198, 0.4784314 , 0.58431375],
#          [0.24705884, 0.45882356, 0.5529412 ]],
#
#         [[0.52156866, 0.6117647 , 0.43137258],
#          [0.5019608 , 0.59607846, 0.40784317],
#          [0.5294118 , 0.6313726 , 0.4431373 ],
#          ...,
#          [0.32156864, 0.7490196 , 0.83921576],
#          [0.17254902, 0.61960787, 0.8980393 ],
#          [0.18039216, 0.62352943, 0.8980393 ]],
#
#         [[0.5882353 , 0.6745098 , 0.53333336],
#          [0.54509807, 0.6431373 , 0.4784314 ],
#          [0.54509807, 0.64705884, 0.46274513],
#          ...,
#          [0.13725491, 0.6666667 , 0.92549026],
#          [0.19607845, 0.65882355, 0.9333334 ],
#          [0.18431373, 0.64705884, 0.9294118 ]]]], dtype=float32)

# %%
model_1.save("D://Users//JC8AB37//Image Classification Model14//model_28.h5")

# %%
model = open('model.pkl','rb')

# %%
# Visualize data (requires function 'view_random_image' above)
plt.figure()
plt.subplot(1, 2, 1)
steak_img = view_random_image("D:/Users/JC8AB37/Image Classification Model14/full data/train/","passed_examples")
plt.subplot(1, 2, 2)
pizza_img = view_random_image("D:/Users/JC8AB37/Image Classification Model14/full data/train/","failed_examples")

# %%
# Plot the validation and training data separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
# Check out the loss curves of model_4
plot_loss_curves(history_1)

# %%
#Data Augmentation

# %%
# Create ImageDataGenerator training instance with data augmentation
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20, # rotate the image slightly between 0 and 20 degrees (note: this is an int not a float)
                                             shear_range=0.2, # shear the image
                                             zoom_range=0.2, # zoom into the image
                                             width_shift_range=0.2, # shift the image width ways
                                             height_shift_range=0.2, # shift the image height ways
                                             horizontal_flip=True) # flip the image on the horizontal axis


# Create ImageDataGenerator test instance without data augmentation
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
# Import data and augment it from training directory
print("Augmented training images:")
train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                                                   target_size=(224, 224),
                                                                   batch_size=32,
                                                                   class_mode='binary',
                                                                   shuffle=False) # Don't shuffle for demonstration purposes, usually a good thing to shuffle

print("Unchanged test images:")
test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=(224, 224),
                                             batch_size=32,
                                             class_mode='binary')

# %%
# Get data batch samples
images, labels = train_data.next()
augmented_images, augmented_labels = train_data_augmented.next() # Note: labels aren't augmented, they stay the same

# %%
# Show original image and augmented image
random_number = random.randint(0, 32) # we're making batches of size 32, so we'll get a random instance
plt.imshow(images[random_number])
plt.title(f"Original image")
plt.axis(False)
plt.figure()
plt.imshow(augmented_images[random_number])
plt.title(f"Augmented image")
plt.axis(False);

# %%
# Create the model (same as model_5)
model_2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(10, 3, activation='relu', input_shape=(224, 224, 3)),
  tf.keras.layers.MaxPool2D(pool_size=2), # reduce number of features by half
  tf.keras.layers.Conv2D(10, 3, activation='relu'),
  tf.keras.layers.MaxPool2D(),
  tf.keras.layers.Conv2D(10, 3, activation='relu'),
  tf.keras.layers.MaxPool2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model_2.compile(loss='binary_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# Fit the model
history_2 = model_2.fit(train_data_augmented, # changed to augmented training data
                        epochs=5,
                        steps_per_epoch=len(train_data_augmented),
                        validation_data=test_data,
                        validation_steps=len(test_data))

# %%
# Create a CNN model (same as Tiny VGG - https://poloclub.github.io/cnn-explainer/)
model_3 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=10, 
                         kernel_size=3, # can also be (3, 3)
                         activation="relu", 
                         input_shape=(224, 224, 3)), # first layer specifies input shape (height, width, colour channels)
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, # pool_size can also be (2, 2)
                            padding="valid"), # padding can also be 'same'
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.Conv2D(10, 3, activation="relu"), # activation='relu' == tf.keras.layers.Activations(tf.nn.relu)
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1, activation="sigmoid") # binary activation output
])

# Compile the model
model_3.compile(loss="binary_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history_3 = model_3.fit(train_data_augmented,
                        epochs=10,
                        steps_per_epoch=len(train_data_augmented),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))

# %%
# Import data and augment it from directories
train_data_augmented_shuffled = train_datagen_augmented.flow_from_directory(train_dir,
                                                                            target_size=(224, 224),
                                                                            batch_size=32,
                                                                            class_mode='binary',
                                                                            shuffle=True)

# %%
model_4 = tf.keras.models.Sequential([
 tf.keras.layers.Conv2D(10, 3, activation='relu', input_shape=(224, 224, 3)),
  tf.keras.layers.MaxPool2D(),
  tf.keras.layers.Conv2D(10, 3, activation='relu'),
  tf.keras.layers.MaxPool2D(),
  tf.keras.layers.Conv2D(10, 3, activation='relu'),
  tf.keras.layers.MaxPool2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model_4.compile(loss='binary_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# Fit the model
history_4 = model_4.fit(train_data_augmented_shuffled, # now the augmented data is shuffled
                        epochs=5,
                        steps_per_epoch=len(train_data_augmented_shuffled),
                        validation_data=test_data,
                        validation_steps=len(test_data))

# %%
#Predictions

# %%
# Classes we're working with
print(class_names)

# %%
passed = mpimg.imread("D:/Users/JC8AB37/Image Classification Model14/full data/train/Passed_Images/20220303_070628.jpg")
plt.imshow(passed)
plt.axis(False);

#20220303_070608.jpg

# %%
failed = mpimg.imread("D:/Users/JC8AB37/Image Classification Model14/full data/train/failed_examples/20220308_093255.jpg")
plt.imshow(failed)
plt.axis(False);

#20220308_093247.jpg

# %%
# Check the shape of our image
passed.shape

# %%
failed.shape

# %%
# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224):
  """
  Reads an image from filename, turns it into a tensor
  and reshapes it to (img_shape, img_shape, colour_channel).
  """
  # Read in target file (an image)
  img = tf.io.read_file(filename)

  # Decode the read file into a tensor & ensure 3 colour channels 
  # (our model is trained on images with 3 colour channels and sometimes images have 4 colour channels)
  img = tf.image.decode_image(img, channels=3)

  # Resize the image (to the same size our model was trained on)
  img = tf.image.resize(img, size = [img_shape, img_shape])

  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  return img

# %%
# Load in and preprocess our custom image
passed = load_and_prep_image("D:/Users/JC8AB37/Image Classification Model14/full data/train/Passed_images/20220303_070628.jpg")
passed

# %%
# Add an extra axis
print(f"Shape before new dimension: {passed.shape}")
passed = tf.expand_dims(passed, axis=0) # add an extra dimension at axis 0
print(f"Shape after new dimension: {passed.shape}")
passed

# %%
# Load in and preprocess our custom image
failed = load_and_prep_image("D:/Users/JC8AB37/Image Classification Model14/full data/train/Passed_images/20220303_070628.jpg")
failed

# %%
# Add an extra axis
print(f"Shape before new dimension: {failed.shape}")
failed = tf.expand_dims(failed, axis=0) # add an extra dimension at axis 0
print(f"Shape after new dimension: {failed.shape}")
failed

# %%
# Make a prediction on custom image tensor
pred = model_1.predict(passed)
pred

# %%
# Make a prediction on custom image tensor
pred = model_1.predict(failed)
pred

# %%
# Remind ourselves of our class names
class_names

# %%
# We can index the predicted class by rounding the prediction probability
pred_class = class_names[int(tf.round(pred)[0][0])]
pred_class

# %%
def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  #pred_class = class_names[int(tf.round(pred)[0][0])]

  print("classnames[0]",pred[0][0])
 # print("classnames[1]",pred[0][1])

  # Plot the image and predicted class
  plt.imshow(img)
  #plt.title(f"Prediction: {pred_class}")
  plt.axis(False);

# %%
# Test our model on a custom image
pred_and_plot(model_1, "D:/Users/JC8AB37/Image Classification Model14/full data/train/Passed_Images/20220303_070628.jpg", class_names)

# %%
# Test our model on a custom image
pred_and_plot(model_1, "D:/Users/JC8AB37/Image Classification Model14/full data/train/failed_examples/20220308_093356.jpg", class_names)

# %%
#Saving and loading our model

# %%
model_1.save("D:/Users/JC8AB37/Image Classification Model14/trained_model_full.h5")

# %%
# Load in a model and evaluate it
loaded_model_11 = tf.keras.models.load_model("D:/Users/JC8AB37/Image Classification Model14/trained_model_full.h5")
loaded_model_11.evaluate(valid_data)

# %%
# Compare our unsaved model's results (same as above)
model_1.evaluate(valid_data)
