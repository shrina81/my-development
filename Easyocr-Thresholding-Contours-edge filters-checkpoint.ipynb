# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
#img = cv2.imread('The Real One.png')
#img = cv2.imread('clientCropped.jpg')
img = cv2.imread('5.jpg')
#img = cv2.imread('newcliientCropped.jpg')
#img = cv2.imread('testClientImage.jpg')
#img = cv2.imread('finalCropped.jpg')
#img = cv2.imread('shrinaCropped.jpg')
#img = cv2.imread('crop6.jpg')
#img = cv2.imread('finalCropped1.jpg')
#img = cv2.imread('onlineCapture.jpg')


print(img.shape)
#img_cropped = img[1000:2500,1000:2500]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
# Out:
# (3024, 4032, 3)

# %%
import cv2
import numpy as np
img = cv2.imread('5.jpg')
height, width = img.shape[:2]
start_row, start_col = int(height*20),int(width*20)
end_row, end_column = int(height*80), int(width*80)
cropped_image = img[start_row:end_row ,start_col:end_column]

cv2.imshow('Original image', img)
cv2.waitKey(0)
cv2.imshow('Cropped image', cropped_image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-54-5c5993a8a518> in <module>
#       9 cv2.imshow('Original image', img)
#      10 cv2.waitKey(0)
# ---> 11 cv2.imshow('Cropped image', cropped_image)
#      12 cv2.waitKey(0)
#      13
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
